# %%
import numpy as np
import csv
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import random
from scipy.optimize import check_grad
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV
import numdifftools as nd
import collections
import pickle as pkl
from sklearn.calibration import CalibratedClassifierCV
import matplotlib
import warnings
import itertools
from scipy.stats.stats import pearsonr
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import normalized_mutual_info_score

# %% [markdown]
# # Load data

# %%
#load data with ids of callworkers
data_ids = pd.read_csv("../../data/ChildWelfare/refer_ids_appended.csv")
data_ids.head()
# Out:
#    REFER_ID SCREENER_SSN_NBR RQST_SSN_NBR APRV_SSN_NBR
# 0    514235          T094595      T071543      T071543
# 1    514236          T094595      T071543      T071543
# 2    514237          T094595      T071543      T071543
# 3    514239          T096208      T096208      T071543
# 4    514240          T096208      T096208      T071543

# %%
#load data containing info on each call
dat_sorted = pd.read_csv("../../data/ChildWelfare/child_welfare_with_call.csv")
dat_sorted = dat_sorted.sort_values(['REFER_DT'])
dat_sorted.drop_duplicates(subset=['MCI_ID'],inplace=True)
dat_sorted.head()
# Out:
#        Unnamed: 0      X    RUN_ID    REFER_DT  REFER_ID      MCI_ID  \
# 64             65     82  10000743  2010-03-31    514286  1000615786
# 63             64     81  10000743  2010-03-31    514286  1000119855
# 62             63     80  10000743  2010-03-31    514286  1000615785
# 61             62     79  10000742  2010-04-01    514285  1000630239
# 44280       44281  46592  10000830  2010-04-01    514375  1000630509
#
#        PL_SCORE  RR_SCORE  AGE_AT_RFRL_CHLD  AGE_AT_RFRL_OTH  \
# 64    -1.612429  0.475528                 0                0
# 63    -1.634500  0.232070                 0                0
# 62    -1.823429  0.313528                 0                0
# 61    -1.739900 -1.316000                 0                0
# 44280 -1.652000 -0.326760                 0                0
#
#               ...           Terrorizing_Child  Throwing  Truancy  \
# 64            ...                           0         0        0
# 63            ...                           0         0        0
# 62            ...                           0         0        0
# 61            ...                           0         0        0
# 44280         ...                           0         0        0
#
#        Tying_OR_Close_Confinement  Ungovernable  \
# 64                              0             0
# 63                              0             0
# 62                              0             0
# 61                              0             0
# 44280                           0             0
#
#        Unlawful_Contact_With_A_Minor  Unreasonably_RestrainingORConfining  \
# 64                                 0                                    0
# 63                                 0                                    0
# 62                                 0                                    0
# 61                                 0                                    0
# 44280                              0                                    0
#
#        WeltsOREcchymosis  Failure_to_Thrive  Inadequate_Clothing
# 64                     0                  0                    0
# 63                     0                  0                    0
# 62                     0                  0                    0
# 61                     0                  0                    0
# 44280                  0                  0                    0
#
# [5 rows x 1043 columns]

# %%
X_call = np.array(dat_sorted.iloc[:,-190:])
cols_call = dat_sorted.columns[-190:]

# %%
dat_sorted.shape
# Out:
# (46544, 1043)

# %%
#columns that should not be used for prediction
col_no_use = ["SCREEN_OUT_NULL","RUN_ID","REFER_DT","REFER_ID","PL_SCORE","RR_SCORE","prediction_random_forests",
                    "REF_2HRS_NULL", 
                    "REF_24HRS_NULL", 
                    "REF_MISTIME_NULL", 
                    "REF_LOW_NULL", 
                    "REF_MOD_NULL", 
                    "REF_HIGH_NULL", 
                    "REF_NORISK_NULL", 
                    "REF_MISRISK_NULL", 
                    "REF_DGR_IMPEND_NULL", 
                    "REF_DGR_PRESENT_NULL", 
                    "REF_DGR_NO_NULL",
                    "REF_DGR_MISSING_NULL",
                    "VERIFIEDOUTCOMES_NULL",
                    "PENDINGCOURT_NULL",
                    "ACCEPTFORSERVICE_NULL",
                    "train_test",
                    "MCI_ID",
                    "DAYS_FROM_LASTRFRL_CHLD",
                    "PREVIOUS_RFRL_CHLD",
                    "RFRL_RANK_CHLD",
                    "RFRL_RANK_OTH",
                    "RFRL_RANK_PERP",
                    "RFRL_RANK_PRNT",
                    "RFRL_RANK_VICT_SELF",
                    "RFRL_RANK_VICT_OTHR",
                     "plsm_nxt730_dummy",
'X','Unnamed: 0']+list(dat_sorted.columns[-195:])

# %%
Y_observed = dat_sorted[['plsm_nxt730_dummy']].values
Y_human = 1-dat_sorted[["SCREEN_OUT_NULL"]].values

refer_ids = dat_sorted[["REFER_ID"]].values

mci_ids = dat_sorted[["MCI_ID"]].values

Y_serv = dat_sorted['ACCEPTFORSERVICE_NULL'].values
Y_sub = dat_sorted['VERIFIEDOUTCOMES_NULL'].values

#remove columns we do not want to use
dat_model = dat_sorted.drop(labels=col_no_use,axis=1)
#remove columns that are always null
dat_model = dat_model.loc[:,((dat_model != 0).any(axis=0))]
dat_model.head()
# Out:
#        AGE_AT_RFRL_VICT_SELF  INFANT_VIC_NULL  TOD_VIC_NULL  PRESC_VIC_NULL  \
# 64                         3                0             0               1
# 63                         4                0             0               1
# 62                         1                0             1               0
# 61                        14                0             0               0
# 44280                      8                0             0               0
#
#        SC1_VIC_NULL  SC2_VIC_NULL  TEEN_VIC_NULL  ADT_VIC_NULL  FEMALE_NULL  \
# 64                0             0              0             0            1
# 63                0             0              0             0            1
# 62                0             0              0             0            0
# 61                0             0              1             0            0
# 44280             1             0              0             0            0
#
#        POVERYRATE_NULL        ...         BIO_MOM_NULL  TOTAL_SUBSTANCE_CHLD  \
# 64                19.6        ...                    1                     0
# 63                19.6        ...                    1                     0
# 62                19.6        ...                    1                     0
# 61                17.0        ...                    0                     0
# 44280             11.4        ...                    0                     0
#
#        TOTAL_SUBSTANCE_OTH  TOTAL_SUBSTANCE_PERP  TOTAL_SUBSTANCE_PRNT  \
# 64                       0                     0                     0
# 63                       0                     0                     0
# 62                       0                     0                     0
# 61                       0                     0                     0
# 44280                    0                     0                     0
#
#        TOTAL_SUBSTANCE_VICT_SELF  TOTAL_SUBSTANCE_VICT_OTHR  BH_SUBSTANCE  \
# 64                             0                          0             0
# 63                             0                          0             0
# 62                             0                          0             0
# 61                             0                          0             0
# 44280                          0                          0             0
#
#        BH_C_20  REF_PAST548_SERV
# 64           0                 3
# 63           0                 2
# 62           0                 2
# 61           0                 0
# 44280        0                 0
#
# [5 rows x 779 columns]

# %%
#create dictionary indicating which decision-maker saw each case
screener_ids_dic = {refer_ids[k][0]:data_ids.loc[data_ids['REFER_ID'] == refer_ids[k][0],'SCREENER_SSN_NBR'].values[0] for k in np.arange(refer_ids.shape[0])}
screener_ids = [data_ids.loc[data_ids['REFER_ID'] == refer_ids[k][0],'SCREENER_SSN_NBR'].values[0] for k in np.arange(refer_ids.shape[0])]
collections.Counter(screener_ids)
# Out:
# Counter({'T095467': 4119,
#          'T096208': 4973,
#          'T060875': 2483,
#          'T084791': 3499,
#          'T091442': 2400,
#          'T094595': 2384,
#          'T044996': 1642,
#          'T066265': 4137,
#          'T071543': 142,
#          'T096966': 2834,
#          'T090937': 6,
#          'T098306': 1245,
#          'T055473': 4877,
#          'T079344': 4547,
#          'T069459': 642,
#          'T092753': 1123,
#          'T096969': 4,
#          'T098337': 701,
#          'T078534': 27,
#          'T087566': 382,
#          'X001435': 3,
#          'T102928': 444,
#          'T102948': 59,
#          'T098938': 33,
#          'T098007': 161,
#          'T083431': 2,
#          'T101142': 2135,
#          'T104299': 196,
#          'T083062': 405,
#          'T101854': 181,
#          'T105008': 43,
#          'T104369': 77,
#          'T105222': 42,
#          'T105208': 30,
#          'T099724': 44,
#          'T105784': 1,
#          'T099665': 495,
#          'T105837': 26})

# %% [markdown]
# ### Select features of X to reduce correlations across features

# %%
#Greedily delete correlated features

def corr_matrix(X):
    M_corr = np.zeros(shape=(X.shape[1],X.shape[1]))
    M_pvalue = np.zeros(shape=(X.shape[1],X.shape[1]))
    for i, j in itertools.combinations(np.arange(X.shape[1]), 2):
        #print(i,j)
        pears = pearsonr(X[:,i], X[:,j])
        M_corr[i,j] = pears[0]
        M_pvalue[i,j] = pears[1]
    return M_corr, M_pvalue

def remove_corr(X,C,columns,tau):
    while np.max(abs(C))>tau:
        idx_maxcor = np.unravel_index(abs(C).argmax(),C.shape)[1]
        print(idx_maxcor)
        print(columns[idx_maxcor])
        #idx_maxcor = idx_maxcor
        columns = np.delete(columns,idx_maxcor)
        C = np.delete(C,idx_maxcor,0)
        C = np.delete(C,idx_maxcor,1)
        X = np.delete(X,idx_maxcor,1)
    return X, C, columns

# %%
X = dat_model.values
colnames = np.array(list(dat_model))

# %%
X.shape
# Out:
# (46544, 779)

# %%
colnames = np.array(list(dat_model))
sel = VarianceThreshold(threshold=(.9* (1 - .9)))
X = sel.fit_transform(X)
colnames = colnames[sel.get_support()]
M_corr, M_pvalue = corr_matrix(X)
X, C, colnames = remove_corr(X, M_corr, colnames, 0.5)
# Out:
# 248
# DPW_OM_1_PER_VICT_SELF
# 245
# DPW_OM_2_PER_VICT_SELF
# 203
# DPW_FS_1_PER_PRNT
# 194
# DPW_FS_3_PER_VICT_SELF
# 199
# DPW_FS_2_PER_VICT_OTHR
# 199
# DPW_FS_1_PER_CHLD
# 201
# DPW_FS_1_PER_VICT_OTHR
# 195
# DPW_FS_2_PER_CHLD
# 198
# DPW_FS_1_PER_PERP
# 198
# DPW_FS_1_PER_VICT_SELF
# 238
# DPW_OM_1_PER_PRNT
# 281
# DPW_TANF_1_PER_PERP
# 194
# DPW_FS_3_PER_VICT_OTHR
# 194
# DPW_FS_2_PER_PERP
# 235
# DPW_OM_1_PER_PERP
# 235
# DPW_OM_1_PER_VICT_OTHR
# 234
# DPW_OM_2_PER_PERP
# 194
# DPW_FS_2_PER_PRNT
# 194
# DPW_FS_2_PER_VICT_SELF
# 231
# DPW_OM_3_PER_PERP
# 192
# DPW_FS_3_PER_PERP
# 192
# DPW_FS_3_PER_PRNT
# 118
# PLSM_PAST548_LOS_NULL
# 103
# FNDG_PAST180_COUNT_VICT_SELF
# 102
# FNDG_PAST180_COUNT_PERP
# 102
# FNDG_PAST180_COUNT_VICT_OTHR
# 237
# DPW_SSI_2_OTH
# 177
# DPW_FS_2_OTH
# 107
# FNDG_PAST548_COUNT_VICT_OTHR
# 234
# DPW_SSI_2_CHLD
# 237
# DPW_SSI_2_VICT_OTHR
# 175
# DPW_FS_2_CHLD
# 233
# DPW_SSI_2_PERP
# 233
# DPW_SSI_2_PRNT
# 233
# DPW_SSI_2_VICT_SELF
# 178
# DPW_FS_2_VICT_OTHR
# 175
# DPW_FS_2_PERP
# 176
# DPW_FS_2_VICT_SELF
# 193
# DPW_GA_2_CHLD
# 103
# FNDG_PAST365_COUNT_VICT_SELF
# 391
# TOTAL_SUBSTANCE_CHLD
# 206
# DPW_OM_2_OTH
# 205
# DPW_OM_2_CHLD
# 174
# DPW_FS_2_PRNT
# 207
# DPW_OM_2_VICT_OTHR
# 104
# FNDG_PAST548_COUNT_PERP
# 103
# FNDG_PAST365_COUNT_VICT_OTHR
# 235
# DPW_TANF_2_CHLD
# 204
# DPW_OM_2_VICT_SELF
# 238
# DPW_TANF_2_VICT_OTHR
# 202
# DPW_OM_2_PERP
# 233
# DPW_TANF_2_OTH
# 233
# DPW_TANF_2_PERP
# 154
# JPO_2_CHLD
# 102
# FNDG_PAST365_COUNT_PERP
# 232
# DPW_TANF_2_VICT_SELF
# 157
# JPO_2_VICT_OTHR
# 199
# DPW_OM_2_PRNT
# 156
# JPO_2_VICT_SELF
# 188
# DPW_GA_2_VICT_SELF
# 227
# DPW_TANF_2_PRNT
# 372
# TOTAL_SUBSTANCE_PERP
# 153
# JPO_2_OTH
# 106
# PLSM_PAST548_COUNT_NULL
# 102
# FNDG_PAST548_COUNT_VICT_SELF
# 152
# JPO_2_PRNT
# 211
# DPW_SSI_1_OTH
# 151
# JPO_2_PERP
# 164
# DPW_FS_1_OTH
# 212
# DPW_SSI_1_VICT_OTHR
# 181
# DPW_GA_2_PRNT
# 163
# DPW_FS_1_CHLD
# 206
# DPW_SSI_1_CHLD
# 362
# TOTAL_SUBSTANCE_VICT_SELF
# 207
# DPW_SSI_1_PRNT
# 139
# ACJ_2_OTH
# 205
# DPW_SSI_1_PERP
# 205
# DPW_SSI_1_VICT_SELF
# 165
# DPW_FS_1_VICT_OTHR
# 162
# DPW_FS_1_PERP
# 103
# PLSM_PAST180_COUNT_NULL
# 174
# DPW_GA_2_OTH
# 105
# PLSM_PAST180_LOS_NULL
# 138
# ACJ_2_PRNT
# 352
# TOTAL_SUBSTANCE_VICT_OTHR
# 172
# DPW_GA_2_PERP
# 21
# VIC_HOUSE_NULL
# 159
# DPW_FS_1_VICT_SELF
# 179
# DPW_OM_1_CHLD
# 179
# DPW_OM_1_OTH
# 158
# DPW_FS_1_PRNT
# 136
# ACJ_2_PERP
# 199
# DPW_TANF_1_CHLD
# 180
# DPW_OM_1_VICT_OTHR
# 119
# DPW_FS_EVERIN_VICT_OTHR
# 178
# DPW_OM_1_VICT_SELF
# 115
# DPW_FS_EVERIN_CHLD
# 199
# DPW_TANF_1_VICT_OTHR
# 175
# DPW_OM_1_PERP
# 195
# DPW_TANF_1_PERP
# 100
# FNDG_PAST90_COUNT_VICT_OTHR
# 193
# DPW_TANF_1_OTH
# 194
# DPW_TANF_1_VICT_SELF
# 88
# REF_PAST548_COUNT_OTH
# 141
# JPO_1_CHLD
# 172
# DPW_OM_1_PRNT
# 113
# DPW_FS_EVERIN_PERP
# 329
# TOTAL_SUBSTANCE_PRNT
# 87
# REF_PAST548_COUNT_CHLD
# 143
# JPO_1_VICT_OTHR
# 113
# DPW_FS_EVERIN_VICT_SELF
# 141
# JPO_1_VICT_SELF
# 185
# DPW_TANF_1_PRNT
# 88
# REF_PAST548_COUNT_PRNT
# 87
# REF_PAST548_COUNT_PERP
# 111
# DPW_OM_EVERIN_CHLD
# 173
# DPW_SSI_3_VICT_SELF
# 137
# JPO_1_PRNT
# 88
# REF_PAST548_COUNT_VICT_OTHR
# 135
# JPO_1_PERP
# 169
# DPW_SSI_3_PRNT
# 316
# BH_SUBSTANCE
# 113
# DPW_OM_EVERIN_VICT_OTHR
# 167
# DPW_SSI_3_PERP
# 133
# JPO_1_OTH
# 307
# PRNT_NON_NULL
# 87
# REF_PAST548_COUNT_VICT_SELF
# 138
# DPW_FS_NOW_CHLD
# 111
# DPW_OM_EVERIN_VICT_SELF
# 34
# PERP_2_NULL
# 94
# PLSM_PAST365_COUNT_NULL
# 138
# DPW_FS_NOW_VICT_OTHR
# 62
# CHLD_FEMALES_NULL
# 131
# DPW_FS_3_PRNT
# 160
# DPW_TANF_3_CHLD
# 88
# SER_PAST548_COUNT_PRNT
# 150
# DPW_OM_NOW_CHLD
# 127
# DPW_FS_3_CHLD
# 295
# CHLD_NON_NULL
# 120
# ACJ_1_PRNT
# 129
# DPW_FS_3_VICT_OTHR
# 129
# DPW_FS_NOW_PERP
# 284
# NO_BH_CHLD
# 28
# VIC_WHITE_NULL
# 117
# ACJ_1_OTH
# 147
# DPW_OM_NOW_VICT_OTHR
# 128
# DPW_FS_NOW_VICT_SELF
# 103
# DPW_FS_EVERIN_PRNT
# 153
# DPW_TANF_3_VICT_OTHR
# 28
# VIC_BLACK_NULL
# 134
# DPW_GA_1_PRNT
# 102
# DPW_OM_EVERIN_PERP
# 149
# DPW_TANF_3_VICT_SELF
# 145
# DPW_SSI_NOW_PERP
# 52
# CHLD_0_NULL
# 48
# PRNT_FEMALES_NULL
# 139
# DPW_OM_NOW_VICT_SELF
# 71
# REF_PAST180_COUNT_CHLD
# 133
# DPW_OM_3_PRNT
# 119
# DPW_FS_3_PERP
# 134
# DPW_OM_NOW_PERP
# 276
# TOTAL_SUBSTANCE_OTH
# 82
# SER_PAST548_COUNT_CHLD
# 117
# DPW_FS_3_OTH
# 139
# DPW_TANF_NOW_PERP
# 137
# DPW_TANF_3_PERP
# 117
# DPW_FS_3_VICT_SELF
# 124
# DPW_GA_1_OTH
# 264
# NO_BH_VICT_OTHR
# 124
# DPW_GA_1_PERP
# 76
# REF_PAST365_COUNT_PERP
# 109
# ACJ_1_PERP
# 267
# REF_PAST548_SERV
# 76
# REF_PAST365_COUNT_PRNT
# 43
# PRNT_OVER2_NULL
# 5
# TEEN_VIC_NULL
# 64
# PREVIOUS_RFRL_PERP
# 57
# CHLD_BLACK_NULL
# 62
# DAYS_FROM_LASTRFRL_VICT_OTHR
# 116
# DPW_OM_3_CHLD
# 61
# DAYS_FROM_LASTRFRL_VICT_SELF
# 124
# DPW_TANF_3_PRNT
# 17
# VIC_1_NULL
# 70
# REF_PAST365_COUNT_VICT_OTHR
# 74
# FNDG_PAST90_COUNT_VICT_SELF
# 84
# ACJ_EVERIN_PRNT
# 252
# BIO_MOM_NULL
# 90
# DPW_TANF_EVERIN_CHLD
# 38
# PRNT_0_NULL
# 112
# DPW_OM_3_VICT_OTHR
# 85
# DPW_OM_EVERIN_PRNT
# 36
# PERP_BLACK_NULL
# 50
# CHLD_AGE_SC2_NULL
# 108
# DPW_OM_3_VICT_SELF
# 44
# PRNT_BLACK_NULL
# 88
# DPW_TANF_EVERIN_VICT_OTHR
# 104
# DPW_OM_3_OTH
# 11
# RACE_BLACK_NULL
# 34
# PERP_WHITE_NULL
# 240
# BH_C_20
# 54
# PREVIOUS_RFRL_PRNT
# 7
# POVERTY_UNDER10_NULL
# 235
# PERP_NON_NULL
# 69
# IN_AJD_CHLD
# 45
# CHLD_AGE_SC1_NULL
# 81
# DPW_TANF_EVERIN_VICT_SELF
# 97
# DPW_OM_3_PERP
# 45
# CHLD_AGE_TEEN_NULL
# 23
# VIC_FEMALES_NULL
# 51
# PREVIOUS_RFRL_VICT_OTHR
# 63
# PLSM_PAST90_LOS_NULL
# 36
# PRNT_AGE_2534_NULL
# 58
# SER_PAST365_COUNT_PRNT
# 18
# VIC_AGE_TOD_NULL
# 72
# DPW_TANF_EVERIN_PERP
# 82
# DPW_FS_NOW_PRNT
# 68
# JPO_EVERIN_PRNT
# 52
# REF_PAST180_COUNT_VICT_OTHR
# 37
# PRNT_WHITE_NULL
# 21
# VIC_AGE_TEEN_NULL
# 60
# IN_AJD_PRNT
# 50
# REF_PAST365_COUNT_CHLD
# 34
# PRNT_AGE_3544_NULL
# 8
# POVERTY_UNDER30_NULL
# 37
# CHLD_AGE_PRE_NULL

# %%
X = np.hstack((X, np.ones((X.shape[0],1))))
scaler = sklearn.preprocessing.StandardScaler()
X = scaler.fit_transform(X)

# %%
df_count = (dat_model[colnames]!=0).sum(axis=0)
(pd.DataFrame(df_count)).sort_values(by=0,ascending=False)
# Out:
#                              0
# VIC_COUNT_NULL           46544
# POVERYRATE_NULL          45516
# PERP_COUNT_NULL          43476
# AGE_AT_RFRL_VICT_SELF    40268
# NO_BH_VICT_SELF          37683
# PRNT_COUNT_NULL          36548
# PERP_1_NULL              35232
# PERP_FEMALES_NULL        32180
# NO_BH_PERP               28743
# NO_BH_PRNT               26849
# IN_AJD_PERP              26437
# FEMALE_NULL              23218
# OTHER_NON_NULL           23166
# BIO_DAD_NULL             22130
# IN_MF_NULL               21690
# CHLD_COUNT_NULL          21219
# VIC_2_NULL               20450
# PRNT_1_NULL              19896
# RACE_WHITE_NULL          19284
# PERP_AGE_2534_NULL       17737
# POVERTY_UNDER20_NULL     16519
# IN_AJD_VICT_SELF         15601
# DAYS_FROM_LASTRFRL_PERP  13762
# IN_AJD_VICT_OTHR         13266
# VIC_AGE_SC2_NULL         12449
# PERP_AGE_3544_NULL       12389
# PRNT_2_NULL              11517
# DAYS_FROM_LASTRFRL_PRNT  11307
# VIC_AGE_PRE_NULL         11202
# VIC_AGE_SC1_NULL         11121
# ...                        ...
# TOTAL_C_31_VICT_OTHR        58
# DPW_GA_3_CHLD               56
# TOTAL_C_28_VICT_SELF        55
# TOTAL_C_14_VICT_SELF        55
# TOTAL_C_14_VICT_OTHR        47
# TOTAL_C_32_VICT_SELF        47
# TOTAL_C_31_VICT_SELF        45
# DPW_GA_3_VICT_SELF          45
# TOTAL_C_32_VICT_OTHR        44
# TOTAL_C_27_PERP             43
# TOTAL_C_33_VICT_OTHR        34
# TOTAL_C_32_CHLD             34
# TOTAL_C_14_CHLD             33
# DPW_GA_3_VICT_OTHR          31
# TOTAL_C_22_VICT_SELF        31
# TOTAL_C_17_PRNT             29
# TOTAL_C_30_OTH              28
# TOTAL_C_21_VICT_SELF        25
# TOTAL_C_22_CHLD             22
# TOTAL_C_18_CHLD             22
# TOTAL_C_22_VICT_OTHR        22
# TOTAL_C_33_VICT_SELF        21
# TOTAL_C_18_VICT_SELF        19
# TOTAL_C_9_VICT_OTHR         15
# TOTAL_C_33_CHLD             12
# TOTAL_C_29_PERP             11
# TOTAL_C_18_VICT_OTHR        11
# TOTAL_C_13_PRNT              7
# TOTAL_C_9_VICT_SELF          7
# TOTAL_C_13_PERP              5
#
# [215 rows x 1 columns]

# %%
#colnames
X.shape
# Out:
# (46544, 216)

# %%
with open('../../data/ChildWelfare/X_preprocess.pkl', 'wb') as file:
    pkl.dump([X,screener_ids,refer_ids,Y_observed,Y_human,Y_serv,Y_sub,colnames],file)
